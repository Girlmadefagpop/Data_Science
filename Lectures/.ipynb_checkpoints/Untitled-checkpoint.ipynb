# %% [markdown]
# ## Outline
#
# - Permutation testing - Applying our 'simulation method' to differences between means
# - Permutation testing - mosquitoes and beer (remember these?)
#         - the less simplified version - includes issues of data wrangling
#         - if you look at the original paper you'll see that the stats are different than what you get in the example from the textbook
#         - that is because the example uses a simplified measure
#         - We will use a real measure and that requires some data wrangling
#         - Our value will be closer to the paper's value
# - Python: merging dataframes
